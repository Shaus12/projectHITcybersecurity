# %% [markdown]
# # 🛡️ Malware Detection EDA and Modeling
# This notebook covers the Exploratory Data Analysis and training of the Malware Classification model.

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## Load Data

# %%
df = pd.read_csv('../data/pe_malware_dataset.csv')
df.head()

# %% [markdown]
# ## Exploratory Data Analysis

# %%
sns.pairplot(df, hue='Label')
plt.show()
